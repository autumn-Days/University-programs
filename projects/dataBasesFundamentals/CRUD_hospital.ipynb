# %% [markdown]
# Para cada item do CRUD eu criei uma "tela" no jupyter. Foi bastante desafiador porque foi a minha primeira experiência com GUI's. Como a senhora disse na descrição do projeto que cada integrante do grupo tinha que fazer 2 telas de CRUD, fiz as telas de paciente e médico (já que só tem eu no grupo). Espero que se divirta !

# %%
from datetime import datetime
import ipywidgets as widgets
from IPython.display import display
from ipywidgets import interact
import pandas as pd
import psycopg2 as pg
import sqlalchemy
from sqlalchemy import create_engine

# %%
cnx = 'postgresql://postgres:postgres@localhost/hospital'
sqlalchemy.create_engine(cnx)
# Out:
# Engine(postgresql://postgres:***@localhost/hospital)

# %%
con = pg.connect(host='localhost', dbname= 'hospital2', user='postgres', password= 'postgres')

# %%
#CRUD do paciente

# %%
#Create paciente

# %%
#declare esta variável para usar na consulta de campos em branco
flag=''

#reseto o valor dos widgets de qualquer tipo de usuário
def resetar_valor_widget(lista_widgets):
    for widget in lista_widgets:
        if isinstance(widget, widgets.Text):
            widget.value = ''
        else:
            widget.value = None


#widgets do paciente
cpf_pac = widgets.Text(
    value='',
    placeholder='Digite seu CPF',
    description='CPF: ',
    disabled=False
)

pnome_pac = widgets.Text(
    value='',
    placeholder='Digite o seu primeiro nome',
    description='Nome: ',
    disabled=False
)

sobrenome_pac = widgets.Text(
    value='',
    placeholder='Digite o seu sobrenome',
    description='Sobrenome: ',
    disabled=False
)

data_nasc_pac = widgets.DatePicker(
    description='DataNasc: ',
    disabled=False
)

# campo com opções enumeradas (radio button)
genero_pac = widgets.RadioButtons(
    options=['M', 'F'],
    description='sexo:',
    disabled=False
)

#begin endereço paciente
cidade_pac = widgets.Text(
    value='',
    placeholder='Digite a sua cidade de residência',
    description='Cidade: ',
    disabled=False
)

bairro_pac = widgets.Text(
    value='',
    placeholder='Digite o seu bairro de residência',
    description='Bairro: ',
    disabled=False
)

rua_pac = widgets.Text(
    value='',
    placeholder='Digite a sua rua de residência',
    description='Rua: ',
    disabled=False
)

numero_casa_pac = widgets.Text(
    value='',
    placeholder='Digite a sua rua de residência',
    description='Número: ',
    disabled=False
)

email_pac = widgets.Text(
    value='',
    placeholder='Digite o seu E-mail',
    description='Email: ',
    disabled=False
)

senha_pac = widgets.Text(
    value='',
    placeholder='Digite uma senha de acesso',
    description='Senha: ',
    disabled=False
)

#end endereço paciente

telefone_pac = widgets.Text(
    value='',
    placeholder='Digite seu telefône',
    description='Seu telefone: ',
    disabled=False
)

telefone_emergencia_pac = widgets.Text(
    value='',
    placeholder='Digite um telefône de emergência',
    description='Telefone emergência: ',
    disabled=False
)

alergias_pac = widgets.Text(
    value='',
    placeholder='Informe uma alergia',
    description='Alergia: ',
    disabled=False
)

#Um widget feito para encontrar o CPF de qualquer tipo de usuário
#Para realizar o update
cpf_chave = widgets.Text(
    value='',
    placeholder='Digite seu CPF',
    description='CPF: ',
    disabled=False
)

all_widgets_pac = [
    cpf_pac, pnome_pac, sobrenome_pac, data_nasc_pac, genero_pac,
    cidade_pac, bairro_pac, rua_pac, numero_casa_pac, email_pac, senha_pac,
    telefone_pac, telefone_emergencia_pac, alergias_pac
]


button_inserir_pac = widgets.Button(description="Inserir", value='')


# ação que vai ser executada ao clicar no botão
# inserir
def on_button_clicked_insert_pac(b):
    try:
        cursor= con.cursor()
        cursor.execute("INSERT INTO paciente(CPF_pac, nome_pac, sobrenome_pac, data_nascimento_pac, genero_pac, cidade_pac, bairro_pac, rua_pac, numero_casa_pac, senha_pac, email_pac) VALUES (%s, %s, %s, %s, %s, %s, %s, %s,%s, %s, %s)", 
                    (cpf_pac.value, pnome_pac.value, sobrenome_pac.value,
                     data_nasc_pac.value, genero_pac.value, cidade_pac.value, bairro_pac.value,
                     rua_pac.value, numero_casa_pac.value, senha_pac.value, email_pac.value,)) #PAY ATTENTION AT THIS FINAL COMMA
        cursor.query
        con.commit()
        
        #df = pd.read_sql("SELECT * FROM paciente", cnx)#This part can be better used in the consult part
        output.clear_output()
        display(pnome_pac,sobrenome_pac,cpf_pac,genero_pac,data_nasc_pac,cidade_pac,bairro_pac,rua_pac,numero_casa_pac,email_pac,senha_pac, button_inserir_pac)
        
    except:
        cursor.execute("ROLLBACK")
        output.clear_output()        
        display(pnome_pac,sobrenome_pac,cpf_pac,genero_pac,data_nasc_pac,cidade_pac,bairro_pac,rua_pac,numero_casa_pac,email_pac,senha_pac, button_inserir_pac, button_inserir_pac)
        display("Não foi possível realizar a inserção. Verifique restrições.")
        
    finally:
        cursor.close()

# botão de inserir 
button_inserir_pac.on_click(on_button_clicked_insert_pac)


#saída da tela
output = widgets.Output()


    
with output:
    output.clear_output()   
    display(pnome_pac,sobrenome_pac,cpf_pac,genero_pac,data_nasc_pac,cidade_pac,bairro_pac,rua_pac,numero_casa_pac,email_pac,senha_pac, button_inserir_pac )
    
output
# Out:
# Output()

# %%
#Consulta do paciente

# %%
cpf_pac = widgets.Text(
    value='',
    placeholder='Digite seu CPF',
    description='CPF: ',
    disabled=False
)

button_visualizar_pac = widgets.Button(description="Visualizar paciente", value='') #definição de botão visualizar
output = widgets.Output()

def on_button_clicked_read_pac(b): #acho que esse "b" significa "botão"
    with output:
        query = f"SELECT * FROM paciente WHERE paciente.CPF_pac = '{cpf_pac.value}';"
        result_df = pd.read_sql_query(query, con)
        cpf_pac.close()
        display(result_df)
        

button_visualizar_pac.on_click(on_button_clicked_read_pac)
display(cpf_pac, button_visualizar_pac, output)

# %%
#DELETE DO PACIENTE

# %%
cpf_pac = widgets.Text(
    value='',
    placeholder='Digite seu CPF',
    description='CPF: ',
    disabled=False
)
button_delete = widgets.Button(description="Deletar", value='Preencha o CPF para deletar')

def on_button_clicked_delete(b):
    try:
        cursor= con.cursor()
        cursor.execute("DELETE FROM paciente WHERE paciente.CPF_pac=%s", (cpf_pac.value,))
        rows_deleted = cursor.rowcount
        con.commit()
        output.clear_output()        
        #display(cpf_pac, button_delete)
    except:
        cursor.execute("ROLLBACK")
        output.clear_output()        
        #display(cpf_pac, button_delete)
        display("Não foi possível realizar deletar. Verifique restrições.")
            
    finally:
        cursor.close()

button_delete.on_click(on_button_clicked_delete)

output = widgets.Output()

with output:
    output.clear_output()   
    display(cpf_pac, button_delete)

output
# Out:
# Output()

# %%
#UPDATE DO PACIENTE

# %% [markdown]
# Eu havia criado esta funcionalidade antes de eu ter notado que na descrição do projeto a senhora não pedia o UPDATE - o que é até bom, pois
# esta implementação não funciona e eu não faço a mínima ideia do porquê, apesar de ter passado 5 horas debugando. Resolvi deixar ela na implementação final do trabalho na esperança de a senhora considerar algo. Caso a senhora queira testar, ele pega o input direitinho, o único problema é que depois ele dá um erro.(Não testei, mas receio que ela quebre o restante do código - o mesmo vale para "UPDATE DO MÉDICO", então, caso queira testá-los, é melhor deixar para o final)

# %%
def pnome_II(lista_valores) :
    novo_dado = input ("Insira o novo primeiro nome")
    lista_valores.append(novo_dado)

def sobrenome_II(lista_valores) :
    novo_dado = input ("Insira o novo sobrenome")
    lista_valores.append(novo_dado)

def genero_II(lista_valores):
    novo_dado = input("Insira o seu gênero:")
    lista_valores.append(novo_dado)

def data_nasc_II(lista_valores):
    novo_dado = input("Insira a sua nova data de nascimento:")
    lista_valores.append(novo_dado)

def cidade_II(lista_valores):
    novo_dado = input("Insira a sua nova cidade de residência:")
    lista_valores.append(novo_dado)

def bairro_II(lista_valores):
    novo_dado = input("Insira o seu novo bairro de residência:")
    lista_valores.append(novo_dado)

def rua_II(lista_valores):
    novo_dado = input("Insira a sua nova rua de residência:")
    lista_valores.append(novo_dado)

def numero_casa_II(lista_valores):
    novo_dado = input("Insira o seu novo número da casa:")
    lista_valores.append(novo_dado)

def email_II(lista_valores):
    novo_dado = input("Insira o seu novo endereço de e-mail:")
    lista_valores.append(novo_dado)

def senha_II(lista_valores):
    novo_dado = input("Insira a sua nova senha de acesso:")
    lista_valores.append(novo_dado)

# %%
def atualizar_pac(cpf):
    lista = []
    pnome_II(lista)
    sobrenome_II(lista)
    data_nasc_II(lista)
    genero_II(lista)
    cidade_II(lista)
    bairro_II(lista)
    rua_II(lista)
    numero_casa_II(lista)
    senha_II(lista)
    email_II(lista)

    pnome_pac.value = str(lista[0])
    sobrenome_pac.value = str(lista[1])
    data_nasc_pac.value = datetime.strptime(datetime.strftime(datetime.strptime(str(lista[2]), "%d/%m/%Y"), "%m/%d/%Y"),"%m/%d/%Y")
    genero_pac.value = str(lista[3])
    cidade_pac.value = str(lista[4])
    bairro_pac.value = str(lista[5])
    rua_pac.value = str(lista[6])
    numero_casa_pac.value = str(lista[7])
    senha_pac.value = str(lista[8])
    email_pac.value = str(lista[9])
    cpf_chave.value = cpf
    
    cursor = con.cursor()
    cursor.execute(
        "UPDATE paciente SET nome_pac = %s, sobrenome_pac = %s, genero_pac = %s, cidade_pac = %s, bairro_pac = %s, rua_pac = %s, numero_casa_pac = %s, senha_pac = %s, email_pac = %s WHERE CPF_pac = %s;",
        (pnome_pac.value, sobrenome_pac.value, genero_pac.value, cidade_pac.value, bairro_pac.value, rua_pac.value, numero_casa_pac.value, senha_pac.value, email_pac.value, cpf_chave.value)
    )

    con.commit()
    output.clear_output()
    cursor.close()

input_manual_cpf = input("Insira o seu CPF para alterar seus dados: ")

atualizar_pac(input_manual_cpf)

# %%
#CREATE MÉDICO

# %%
#declare esta variável para usar na consulta de campos em branco
flag=''

cpf_medico = widgets.Text(
    value='',
    placeholder='Digite seu CPF',
    description='CPF: ',
    disabled=False
)

pnome_medico = widgets.Text(
    value='',
    placeholder='Digite o seu primeiro nome',
    description='Nome: ',
    disabled=False
)

sobrenome_medico = widgets.Text(
    value='',
    placeholder='Digite o seu sobrenome',
    description='Sobrenome: ',
    disabled=False
)

data_nasc_medico = widgets.DatePicker(
    description='Nascimento:',
    disabled=False
)

# campo com opções enumeradas (radio button)
genero_medico = widgets.RadioButtons(
    options=['M', 'F'],
    description='sexo:',
    disabled=False
)

#begin endereço paciente
cidade_medico = widgets.Text(
    value='',
    placeholder='Digite a sua cidade de residência',
    description='Cidade: ',
    disabled=False
)

bairro_medico = widgets.Text(
    value='',
    placeholder='Digite o seu bairro de residência',
    description='Bairro: ',
    disabled=False
)

rua_medico = widgets.Text(
    value='',
    placeholder='Digite a sua rua de residência',
    description='Rua: ',
    disabled=False
)

numero_casa_medico = widgets.IntText( #<----
    value=0,
    placeholder='Digite a sua rua de residência',
    description='Número: ',
    disabled=False
)

email_medico = widgets.Text(
    value='',
    placeholder='Digite o seu E-mail',
    description='Email: ',
    disabled=False
)

senha_medico = widgets.Text(
    value='',
    placeholder='Digite uma senha de acesso',
    description='Senha: ',
    disabled=False
)

especialidade_medico = widgets.Text(
    value='',
    placeholder='Digite sua especialidade',
    description='Especialidade: ',
    disabled=False
)

grau_especializacao_medico = widgets.RadioButtons( #testar depois para ver se é isso
    options=['Bacharel', 'Mestre', 'Doutor'],
    description='Grau de especialização:',
    disabled=False
)

data_contratacao_medico = widgets.DatePicker(
    description='Contratação: ',
    disabled=False
)

horarios_trabalho_medico = widgets.Text(
    value='',
    placeholder='Informe seus horários de trabalho',
    description='horáriosTrab: ',
    disabled=False
)

salario_medico = widgets.FloatText(#Maybe it is related to this FloatText
    value= 0.0,
    placeholder='Informe seu salário: ',
    description='salario: ',
    disabled=False
)

dias_trabalho_medico = widgets.Text(
    value='',
    placeholder='Informe seus dias de trabalho',
    description='DiasTrab: ',
    disabled=False
)

button_inserir_medico = widgets.Button(description="Inserir", value='')


# ação que vai ser executada ao clicar no botão
# inserir
def on_button_clicked_insert_med(b):
    try:
        cursor= con.cursor()
        cursor.execute("INSERT INTO medico(CPF_med, nome_med, sobrenome_med, data_nascimento_med, genero_med, cidade_med, bairro_med, rua_med, numero_casa_med, senha_med, email_med, especialidade_med, data_contratacao_med, horarios_trabalho_med, grau_especializacao_med, salario_med, dias_trabalho_med) VALUES (%s, %s, %s, %s, %s, %s, %s,%s, %s, %s,%s,%s, %s, %s,%s,%s, %s)", 
                    (cpf_medico.value, pnome_medico.value, sobrenome_medico.value,
                     data_nasc_medico.value, genero_medico.value, cidade_medico.value, bairro_medico.value,
                     rua_medico.value, numero_casa_medico.value, senha_medico.value, email_medico.value,
                     especialidade_medico.value, data_contratacao_medico.value, horarios_trabalho_medico.value,
                     grau_especializacao_medico.value, salario_medico.value, dias_trabalho_medico.value,)) #PAY ATTENTION TO THIS FINAL COMMA
        cursor.query
        con.commit()
        
        df = pd.read_sql("SELECT * FROM medico", cnx)#This part can be better used in the consult part
        output.clear_output()
        display(pnome_medico, sobrenome_medico, email_medico,genero_medico, cpf_medico, data_nasc_medico,
                cidade_medico, bairro_medico, rua_medico, numero_casa_medico, data_contratacao_medico,
                grau_especializacao_medico, especialidade_medico, dias_trabalho_medico, horarios_trabalho_medico,
                salario_medico, senha_medico,button_inserir_medico)

    except:
        cursor.execute("ROLLBACK")
        output.clear_output()        
        display(pnome_medico, sobrenome_medico, email_medico,genero_medico, cpf_medico, data_nasc_medico,
                cidade_medico, bairro_medico, rua_medico, numero_casa_medico, data_contratacao_medico,
                grau_especializacao_medico, especialidade_medico, dias_trabalho_medico, horarios_trabalho_medico,
                salario_medico, senha_medico,button_inserir_medico)
        display("Não foi possível realizar a inserção. Verifique restrições.")
        
    finally:
        cursor.close()

# botão de inserir 
button_inserir_medico.on_click(on_button_clicked_insert_med)


#saída da tela
output = widgets.Output()


    
with output:
    output.clear_output()   
    display(pnome_medico, sobrenome_medico, email_medico,genero_medico, cpf_medico, data_nasc_medico,
            cidade_medico, bairro_medico, rua_medico, numero_casa_medico, data_contratacao_medico,
            grau_especializacao_medico, especialidade_medico, dias_trabalho_medico, horarios_trabalho_medico,
            salario_medico, senha_medico, button_inserir_medico)
    
output

# %%
#CONSULTA MÉDICO

# %%
cpf_medico = widgets.Text(
    value='',
    placeholder='Digite seu CPF',
    description='CPF: ',
    disabled=False
)

button_visualizar_medico = widgets.Button(description="Visualizar medico", value='') #definição de botão visualizar
output = widgets.Output()

def on_button_clicked_read_med(b): #acho que esse "b" significa "botão"
    with output:
        query = f"SELECT * FROM medico WHERE medico.CPF_med = '{cpf_medico.value}';"
        result_df = pd.read_sql_query(query, con)
        cpf_pac.close()
        display(result_df)
        

button_visualizar_medico.on_click(on_button_clicked_read_med)
display(cpf_medico, button_visualizar_medico, output)

# %%
#DELETE MÉDICO

# %%
#os dados que não estão "embeded" são apagados, mas os dados que estão não conseguem ser apagados
cpf_medico = widgets.Text(
    value='',
    placeholder='Digite seu CPF',
    description='CPF: ',
    disabled=False
)
button_delete_med = widgets.Button(description="Deletar")

def on_button_clicked_delete_medico(b):
    try:
        print("começou")
        cursor= con.cursor()
        cursor.execute("DELETE FROM medico WHERE medico.CPF_med=%s", (cpf_medico.value,))
        rows_deleted = cursor.rowcount
        con.commit()
        output.clear_output()        
        display(cpf_pac, button_delete)
        print("terminou")
    except:
        print("deu errado")
        cursor.execute("ROLLBACK")
        output.clear_output()        
        display(cpf_pac, button_delete)
        display("Não foi possível realizar deletar. Verifique restrições.")
            
    finally:
         cursor.close()

button_delete_med.on_click(on_button_clicked_delete_medico)

output = widgets.Output()

with output:
    output.clear_output()   
    display(cpf_medico, button_delete_med)

output
# Out:
# Output()

# %%
#UPDATE MÉDICO

# %%
def especialidade_II(lista) :
    novo_dado = input("insira a sua especialidade")
    lista.append(novo_dado)
def data_contratacao_II(lista) :
    novo_dado = input("Insira a sua especialiade")
    lista.append(novo_dado)
def horarios_trabalho_II(lista) :
    novo_dado = input("Insira os seus horários de trabalho")
    lista.append(novo_dado)
def grau_especializacao_II(lista) :
    novo_dado = input("Insira o seu grau de especialização")
    lista.append(novo_dado)
def salario(lista) :
    novo_dado = input("Insira o seu salário")
    lista.append(novo_dado)
def dias_trabalho_II(lista) :
    novo_dado = input("Insira os dias em que você trabalha")
    lista.append(novo_dado)

# %%
def atualizar_med(cpf):
    lista = []
    pnome_II(lista)
    sobrenome_II(lista)
    email_II(lista)
    genero_II(lista)
    data_nasc_II(lista)
    cidade_II(lista)
    bairro_II(lista)
    rua_II(lista)
    numero_casa_II(lista)
    data_contratacao_II(lista)
    salario(lista)
    grau_especializacao_II(lista)
    especialidade_II(lista)
    dias_trabalho_II(lista)
    horarios_trabalho_II(lista)
    senha_II(lista)
    

    pnome_medico.value = str(lista[0])
    sobrenome_medico.value = str(lista[1])
    email_medico.value = str(lista[2])
    genero_medico.value = str(lista[3])
    data_nasc_medico.value = datetime.strptime(datetime.strftime(datetime.strptime(str(lista[4]), "%d/%m/%Y"), "%m/%d/%Y"),"%m/%d/%Y")
    cidade_medico.value = str(lista[5])
    bairro_medico.value = str(lista[6])
    rua_medico.value = str(lista[7])
    numero_casa_medico.value = str(lista[8])
    data_contratacao_medico.value = datetime.strptime(datetime.strftime(datetime.strptime(str(lista[9]), "%d/%m/%Y"), "%m/%d/%Y"),"%m/%d/%Y")
    salario_medico.value = str(lista[10])
    grau_especializacao_medico.value = str(lista[11])
    especialidade_medico.value = str(lista[12])
    dias_trabalho_medico.value = str(lista[13])
    horarios_trabalho_medico.value = str(lista[14])
    senha_medico.value = str(lista[15])
    
    
    cursor = con.cursor()
    cursor.execute(
        "UPDATE paciente SET nome_med = %s,sobrenome_med = %s,data_nascimento_med = %s,genero_med = %s,cidade_med = %s,bairro_med = %s,rua_med = %s,numero_casa_med = %s,senha_med = %s,email_med = %s,especialidade_med = %s,data_contratacao_med = %s,horarios_trabalho_med = %s,grau_especializacao_med = %s,salario_med = %s,dias_trabalho_med WHERE CPF_med = %s;",
        (pnome_medico.value,sobrenome_medico.value,data_nasc_medico.value ,genero_medico.value ,cidade_medico.value,bairro_medico.value,rua_medico.value,numero_casa_medico.value,senha_medico.value ,email_medico.value ,especialidade_medico.value,data_contratacao_medico.value ,horarios_trabalho_medico.value ,grau_especializacao_medico.value ,salario_medico.value ,dias_trabalho_medico.value)
    )

    con.commit()
    output.clear_output()
    cursor.close()

input_manual_cpf = input("Insira o seu CPF para alterar seus dados: ")

atualizar_med(input_manual_cpf)

# %%
#VIEW

# %%
#cb significa "checkbox"
CPF_pac_cb = widgets.Checkbox(value=False, description='CPF_pac')
nome_pac_cb = widgets.Checkbox(value=False, description='nome_pac')
sobrenome_pac_cb = widgets.Checkbox(value=False, description='sobrenome_pac')
data_nascimento_pac_cb = widgets.Checkbox(value=False, description='data_nascimento_pac')
genero_pac_cb = widgets.Checkbox(value=False, description='genero_pac')
cidade_pac_cb = widgets.Checkbox(value=False, description='cidade_pac')
bairro_pac_cb = widgets.Checkbox(value=False, description='bairro_pac')
rua_pac_cb = widgets.Checkbox(value=False, description='rua_pac')
numero_casa_pac_cb = widgets.Checkbox(value=False, description='numero_casa_pac')
senha_pac_cb = widgets.Checkbox(value=False, description='senha_pac')
email_pac_cb = widgets.Checkbox(value=False, description='email_pac')
hotelaria_hospitalar_cb = widgets.Checkbox(value=False, description='nome_hotelaria')


confirmation_button = widgets.Button(description='Confirm')


output = widgets.Output()

def on_button_click(b):
    with output:
        lista_cbs = [CPF_pac_cb, nome_pac_cb, sobrenome_pac_cb,
        data_nascimento_pac_cb, genero_pac_cb, cidade_pac_cb,
        bairro_pac_cb, rua_pac_cb, numero_casa_pac_cb,
        senha_pac_cb, email_pac_cb, hotelaria_hospitalar_cb]
        lista_cbs_vdd = []

        #adiciona todas as colunas que o usuário quer ver em uma lista
        for cb in lista_cbs :
            if cb.value == True :
                lista_cbs_vdd.append("relatorio_geral." + cb.description)
        
        

        #separo as colunas que o usuário quer ver em uma string, separando as por vírgula
        all_selections = ""
        
        for cb in lista_cbs_vdd :
            all_selections += cb + ","
        
        all_selections = all_selections[:-1] #remove a última vírgula
        print(all_selections)

        query = f"SELECT {all_selections} FROM relatorio_geral;"
        result_df = pd.read_sql_query(query, con)
        
        
        CPF_pac_cb.close()
        nome_pac_cb.close()
        sobrenome_pac_cb.close()
        data_nascimento_pac_cb.close()
        genero_pac_cb.close()
        cidade_pac_cb.close()
        bairro_pac_cb.close()
        rua_pac_cb.close()
        numero_casa_pac_cb.close()
        senha_pac_cb.close()
        email_pac_cb.close()
        hotelaria_hospitalar_cb.close()

        display(result_df)


confirmation_button.on_click(on_button_click)


display(CPF_pac_cb, nome_pac_cb, sobrenome_pac_cb,
        data_nascimento_pac_cb, genero_pac_cb, cidade_pac_cb,
        bairro_pac_cb, rua_pac_cb, numero_casa_pac_cb,
        senha_pac_cb, email_pac_cb, hotelaria_hospitalar_cb, confirmation_button, output)
